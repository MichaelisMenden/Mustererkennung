# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy.polynomial.polynomial as poly
import sklearn
from sklearn.svm import SVR

# %%
data = np.array([1,1.5,3,1,7,8.5,9,9,13,10,11.5,10])
x = np.array([0,1,2,3,4,7,8,9,10,11,12,13])
plt.plot(x,data,'r.')
plt.title('Daten')
x
# Out:
# array([ 0,  1,  2,  3,  4,  7,  8,  9, 10, 11, 12, 13])

# %%
coefs = poly.polyfit(x,data, 1)
ffit = poly.Polynomial(coefs)
plt.plot(ffit(np.arange(0, 14, 1)))
plt.plot(x,data,'r.')
plt.title('Lineare Regression')
# Out:
# Text(0.5,1,'Lineare Regression')

# %%
coefs = poly.polyfit(x,data, 2)
ffit = poly.Polynomial(coefs)
plt.plot(x,data,'r.')
plt.plot(ffit(np.arange(0, 14, 1)))
plt.title('Nichtlineare Regression Polynom 2.Grades')
# Out:
# Text(0.5,1,'Nichtlineare Regression Polynom 2.Grades')

# %%
coefs = poly.polyfit(x,data, 3)
ffit = poly.Polynomial(coefs)
plt.plot(x,data,'r.')
plt.plot(ffit(np.arange(0, 14, 1)))
plt.title('Nichtlineare Regression Polynom 3.Grades')
# Out:
# Text(0.5,1,'Nichtlineare Regression Polynom 3.Grades')

# %%
coefs = poly.polyfit(x,data, 5)
ffit = poly.Polynomial(coefs)
plt.plot(x,data,'r.')
plt.plot(ffit(np.arange(0, 14, 1)))
plt.title('Nichtlineare Regression Polynom 5.Grades')
# Out:
# Text(0.5,1,'Nichtlineare Regression Polynom 5.Grades')

# %% [markdown]
# Je höher der Grad des Polynoms desto besser ist die Anpassung an die Daten. Hierbei besteht allerdings die Gefahr des Overfittings, sodass die Daten "auswendig gelernt werden.

# %%
#svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.1)
#svr_lin = SVR(kernel='linear', C=1e5)
svr_poly = SVR(kernel='poly', C=1e5, degree=2)

# %%
data = np.array([[1],[1.5],[3],[1],[7],[8.5],[9],[9],[13],[10],[11.5],[10]])
#y_rbf = svr_rbf.fit(data, np.arange(0, 12, 1)).predict(data)
#y_lin = svr_lin.fit(data, np.arange(0, 12, 1)).predict(data)
y_poly = svr_poly.fit(data, np.arange(0, 12, 1)).predict(data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-f46f7d05b373> in <module>()
#       2 #y_rbf = svr_rbf.fit(data, np.arange(0, 12, 1)).predict(data)
#       3 #y_lin = svr_lin.fit(data, np.arange(0, 12, 1)).predict(data)
# ----> 4 y_poly = svr_poly.fit(data, np.arange(0, 12, 1)).predict(data)
#
# ~\Anaconda3\lib\site-packages\sklearn\svm\base.py in fit(self, X, y, sample_weight)
#     185
#     186         seed = rnd.randint(np.iinfo('i').max)
# --> 187         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     188         # see comment on the other call to np.iinfo in this file
#     189
#
# ~\Anaconda3\lib\site-packages\sklearn\svm\base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     252                 cache_size=self.cache_size, coef0=self.coef0,
#     253                 gamma=self._gamma, epsilon=self.epsilon,
# --> 254                 max_iter=self.max_iter, random_seed=random_seed)
#     255
#     256         self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
lw = 2
plt.scatter(data, np.arange(0, 12, 1), color='darkorange', label='data')
#plt.plot(data, y_rbf, color='navy', lw=lw, label='RBF model')
#plt.plot(data, y_lin, color='c', lw=lw, label='Linear model')
plt.plot(data, y_poly, color='cornflowerblue', lw=lw, label='Polynomial model')
plt.xlabel('data')
plt.ylabel('target')
plt.title('Support Vector Regression')
plt.legend()
plt.show()
